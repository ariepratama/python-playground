# %% [markdown]
# # Get wikidata definition from freebase ids
#
# this notebook will show you how to query freebase ids from wikidata SPARSQL and save it into your local. I will use `simple_questions_v2` freebase ids as an example, on how to download all the entities from wikidata.
#
# Downloading the whole set of entities from wikidata might require large storage, thus I will not do that in this tutorial.

# %%
from datasets import load_dataset
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
train = load_dataset("simple_questions_v2", split="train")
test = load_dataset("simple_questions_v2", split="test")
valid = load_dataset("simple_questions_v2", split="validation")

# %% [markdown]
# collate all the freebase entities from `train`, `test`, and `valid` set.

# %%
entities = set(train["subject_entity"])
entities.update(set(train["object_entity"]))
entities.update(set(test["subject_entity"]))
entities.update(set(test["object_entity"]))
entities.update(set(valid["subject_entity"]))
entities.update(set(valid["object_entity"]))

# %%
entities = list(entities)

# %%
entities[0]
# Out:
# 'www.freebase.com/m/02y8k7'

# %%
transformed_entities = ["/" + "/".join(e.split("/")[1:]) for e in entities]
len(transformed_entities)
# Out:
# 95832

# %% [markdown]
# ## Constructing the wikidata SPARSQL
#
# This is the sample SPARSQL query to get freebase definition from wikidata. I will need to replace the freebase id, e.g: `/m/017stm`, into something else.
#
# ```
# PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#
# SELECT ?item ?itemLabel
#
# WHERE
# {
#   {?item wdt:P646 "/m/017stm" .}
#
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en"  }
# }
# LIMIT 1
# ```

# %%
# item_template = "{?item wdt:P646 \"{}\" .}"
def construct_items(items):
    item_prefix = '''\t{?item wdt:P646 "'''
    item_suffix = '''" .}'''
    if len(items) == 1:
        return item_prefix + items[0] + item_suffix

    item_lines = [item_prefix + items[0] + item_suffix]
    for i in range(1, len(items)):
        item_line = item_prefix + items[i] + item_suffix
        item_lines.append(
            f"\tUNION {item_line}"
        )
    return "\n".join(item_lines)

def construct_query(items):
    """ construct SPARSQL query to get all freebase entities itemLabel from wikidata.
    will need to show the freebaseId since not everything will be available in wikidata
    """
    query_template = """
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT ?item ?itemLabel ?freebaseId

WHERE
{{
  \t{{?item wdt:P646 ?freebaseId.}}
  {}
  SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en"  }}
}}
LIMIT {}
"""
    limit = len(items)
    where_items = construct_items(items)
    return query_template.format(where_items, limit)

# %%
def get_wikidata_definitions(items) -> dict:
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    sparql.setQuery(construct_query(items))
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %% [markdown]
# ## Download labels from wikidata
#
# We should download the mappings from wikidata to prevent us to query multiple times. In this example, I will only use 5 concurrent connections / threads and queue the rest using `ThreadPoolExecutor`. In addition, I will show how to download multiple entities in one network call (I used 110 entities per download request) to make the downloading faster.

# %%
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm

# %%
# max wikidata concurrent api call limit
tp = ThreadPoolExecutor(5)

# %%
# limited by the length of the request
batch_size = 110
iteration_size = len(transformed_entities) // batch_size  + 1

batch_idxs = [
    (i, min(i + batch_size, len(transformed_entities))) 
    for i in range(0, len(transformed_entities), batch_size)
]

batched_entities = [
    transformed_entities[start:end]
    for start, end in batch_idxs
]

# %%
# adding batch index, batch_i, so that we would know which part should be retried
# sample results:
# {'head': {'vars': ['item', 'itemLabel', 'freebaseId']},
 # 'results': {'bindings': [{'item': {'type': 'uri',
 #     'value': 'http://www.wikidata.org/entity/Q474472'},
 #    'freebaseId': {'type': 'literal', 'value': '/m/03ydz4'},
 #    'itemLabel': {'xml:lang': 'en',
 #     'type': 'literal',
 #     'value': 'Pale Blue Dot'}},
futures = []
for batch_i, batch in enumerate(batched_entities):
    future = tp.submit(get_wikidata_definitions, batch)
    futures.append((batch_i, future))

results = []
for batch_i, future in tqdm(futures):
    future_result = None
    try:
        future_result = future.result()
    except exception as e:
        print(f"{batch_i} has error when downloading request", e)
    finally:
        results.append((batch_i, future_result))
# Out:
#   0%|          | 0/872 [00:00<?, ?it/s]

# %% [markdown]
# printing sample of batch

# %%
batched_entities[112]
# Out:
# ['/m/01b6ypn',
#  '/m/03ydz4',
#  '/m/0mx1wbd',
#  '/m/075vbf7',
#  '/m/07ldlv6',
#  '/m/08bm2c',
#  '/m/031hcyy',
#  '/m/0lg0r',
#  '/m/03fgcqn',
#  '/m/0bwgcr4',
#  '/m/0fq2dp5',
#  '/m/05zstm1',
#  '/m/01wkf0',
#  '/m/02761m',
#  '/m/0950y7',
#  '/m/043lhbd',
#  '/m/040g7m4',
#  '/m/05tk7nn',
#  '/m/0b6scj1',
#  '/m/026b0b9',
#  '/m/03tgpg',
#  '/m/0sphh8n',
#  '/m/0gpgt2',
#  '/m/02z32xg',
#  '/m/0mb7qmq',
#  '/m/05q0fns',
#  '/m/0k_b2yr',
#  '/m/06rwtb',
#  '/m/07jz1d',
#  '/m/07llhg',
#  '/m/0f73bpd',
#  '/m/05c7rj_',
#  '/m/05syz_4',
#  '/m/0k_s',
#  '/m/068f10',
#  '/m/03y56dp',
#  '/m/01mnfmv',
#  '/m/01n4nd',
#  '/m/04p41k6',
#  '/m/0sds94',
#  '/m/07lt8dz',
#  '/m/0bhd1qg',
#  '/m/0ckk2',
#  '/m/03gvsvn',
#  '/m/0fvzlwl',
#  '/m/0fth4fk',
#  '/m/0fk436',
#  '/m/03fndm9',
#  '/m/0cw4h1',
#  '/m/0906pq',
#  '/m/0srn0j',
#  '/m/01g53pl',
#  '/m/0m56y',
#  '/m/0ks9w4',
#  '/m/07l3ny',
#  '/m/04yc3p',
#  '/m/0g0pvm7',
#  '/m/04vxdn5',
#  '/m/028db2',
#  '/m/02j2gg',
#  '/m/0kx53',
#  '/m/03hj2_g',
#  '/m/04whjzm',
#  '/m/0n51f',
#  '/m/0ckdv',
#  '/m/035b3s4',
#  '/m/0fl35',
#  '/m/02hm2fw',
#  '/m/02rh1jd',
#  '/m/0hp7sqm',
#  '/m/0ksstb',
#  '/m/0c14by',
#  '/m/04b9mt2',
#  '/m/0b1twg',
#  '/m/02w57zf',
#  '/m/025zh4',
#  '/m/01shfr0',
#  '/m/02lkt',
#  '/m/03s8_d4',
#  '/m/04wqr',
#  '/m/0ggrjb',
#  '/m/03cwn7k',
#  '/m/03pfhy',
#  '/m/025r_8f',
#  '/m/0qhc_fz',
#  '/m/02vxn63',
#  '/m/036xygl',
#  '/m/04cy42p',
#  '/m/0h698tz',
#  '/m/0g1vsn6',
#  '/m/014rgt',
#  '/m/0493tr9',
#  '/m/0shq5fh',
#  '/m/026x72q',
#  '/m/049tt',
#  '/m/01l2qwn',
#  '/m/0b780xp',
#  '/m/081_zm',
#  '/m/0nq14p7',
#  '/m/02820z5',
#  '/m/0kpytg',
#  '/m/0qk6jx',
#  '/m/02rn99',
#  '/m/03g3p4s',
#  '/m/02q_qs',
#  '/m/0dp6z0_',
#  '/m/04144xy',
#  '/m/0fx63tj',
#  '/m/026xg3k',
#  '/m/01mvd2h']

# %%
batch_id, res = results[112]
res
# Out:
# {'head': {'vars': ['item', 'itemLabel', 'freebaseId']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q774'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0345_'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Guatemala'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q108137'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0l2l_'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Napa County'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3883950'},
#     'freebaseId': {'type': 'literal', 'value': '/m/026h8l'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Operation Colossus'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5151337'},
#     'freebaseId': {'type': 'literal', 'value': '/m/07flx6'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Come On-a My House'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6732326'},
#     'freebaseId': {'type': 'literal', 'value': '/m/053b7q'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Magomed Omarov'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q467156'},
#     'freebaseId': {'type': 'literal', 'value': '/m/01dlbx'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'David Halberstam'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q429316'},
#     'freebaseId': {'type': 'literal', 'value': '/m/043xxb'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Stardock'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q62730'},
#     'freebaseId': {'type': 'literal', 'value': '/m/02h22'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Das Boot'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1678883'},
#     'freebaseId': {'type': 'literal', 'value': '/m/049c03'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Richard North Patterson'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2415074'},
#     'freebaseId': {'type': 'literal', 'value': '/m/02x9q6y'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Night Heaven Fell'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4992506'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0g3vj6'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Kenneth Biller'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q714491'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0146qg'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Marks & Spencer'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5500120'},
#     'freebaseId': {'type': 'literal', 'value': '/m/04cx2pg'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Free Touching: Live in Beijing at Keep in Touch'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q303891'},
#     'freebaseId': {'type': 'literal', 'value': '/m/03tf_h'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Lewis Gilbert'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q189074'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0f94t'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Harlem'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5303187'},
#     'freebaseId': {'type': 'literal', 'value': '/m/02z9hcz'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Downieville'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q6221'},
#     'freebaseId': {'type': 'literal', 'value': '/m/01tsq8'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brescia'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q123006'},
#     'freebaseId': {'type': 'literal', 'value': '/m/049tt'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kabbalah'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7610134'},
#     'freebaseId': {'type': 'literal', 'value': '/m/05zq9l_'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Stephen Oduro'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q114219'},
#     'freebaseId': {'type': 'literal', 'value': '/m/02q4138'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Amir Muhammad'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q114219'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0550_1'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Amir Muhammad'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q143744'},
#     'freebaseId': {'type': 'literal', 'value': '/m/03y171z'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': '1787 Chiny'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7293936'},
#     'freebaseId': {'type': 'literal', 'value': '/m/01slj20'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Raphael'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q523899'},
#     'freebaseId': {'type': 'literal', 'value': '/m/01vc5rm'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Cootie Williams'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5149805'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0ch45lk'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Columbia Railroad Bridge'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q12233'},
#     'freebaseId': {'type': 'literal', 'value': '/m/016d7r'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Santander'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1257444'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0290sh6'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'film adaptation'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1257444'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0cq22fy'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'film adaptation'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1711'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0d331'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Potsdam'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2859185'},
#     'freebaseId': {'type': 'literal', 'value': '/m/052jfh'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'New England Aquarium'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6672492'},
#     'freebaseId': {'type': 'literal', 'value': '/m/05q5zrg'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Long Da Lishkara'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q15695277'},
#     'freebaseId': {'type': 'literal', 'value': '/m/05q5zrg'},
#     'itemLabel': {'type': 'literal', 'value': 'Q15695277'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q777737'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0267qzd'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': '5011 Ptah'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2964736'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0bm8s6h'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chris Hill'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q500035'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0371q5'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Toyota Camry'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1016790'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0cz9kc_'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Burning Bright'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1137742'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0h2tqf'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Plow Boy'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q316610'},
#     'freebaseId': {'type': 'literal', 'value': '/m/04mhl'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Larry Niven'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q703897'},
#     'freebaseId': {'type': 'literal', 'value': '/m/05lnk0'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tom DeFalco'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3711'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0fhzf'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belgrade'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4391998'},
#     'freebaseId': {'type': 'literal', 'value': '/m/09gj8s9'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Jesse Stone: Sea Change'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q739612'},
#     'freebaseId': {'type': 'literal', 'value': '/m/039qq6'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Matsumoto Castle'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7422453'},
#     'freebaseId': {'type': 'literal', 'value': '/m/065zr77'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Sarah Jarosz'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1173707'},
#     'freebaseId': {'type': 'literal', 'value': '/m/027xg1w'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Night of the Pencils'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5214209'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0839rv'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dan Plesac'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q52081'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0bztr4'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Foiano della Chiana'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1462034'},
#     'freebaseId': {'type': 'literal', 'value': '/m/07zdsc'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Moontrap'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q695417'},
#     'freebaseId': {'type': 'literal', 'value': '/m/010rvx'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bremerton'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q489951'},
#     'freebaseId': {'type': 'literal', 'value': '/m/06qn87'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Geoffrey Unsworth'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6037962'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0h3hfp'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Inside the Mind of Bill Cosby'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q164765'},
#     'freebaseId': {'type': 'literal', 'value': '/m/03101c'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Alexander Blok'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2184868'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0z8wx'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Prue'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q150827'},
#     'freebaseId': {'type': 'literal', 'value': '/m/02zlm'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Frankenstein; or, The Modern Prometheus'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7460285'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0j61__g'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Shadeed'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q228871'},
#     'freebaseId': {'type': 'literal', 'value': '/m/06qgvf'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Carla Gugino'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1429262'},
#     'freebaseId': {'type': 'literal', 'value': '/m/02qk02l'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Flora Hastings'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5248488'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0bs661h'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Debra Lehrmann'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9876'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0vlvp'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Vught'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2002196'},
#     'freebaseId': {'type': 'literal', 'value': '/m/04652t'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Oldsmobile Cutlass Calais'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11982'},
#     'freebaseId': {'type': 'literal', 'value': '/m/06458'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'photosynthesis'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7752483'},
#     'freebaseId': {'type': 'literal', 'value': '/m/04wh9v9'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Mountain Meadows Massacre'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4787285'},
#     'freebaseId': {'type': 'literal', 'value': '/m/018wwv'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Archives New Zealand'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1248594'},
#     'freebaseId': {'type': 'literal', 'value': '/m/05x1_j'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Resident Evil'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4864216'},
#     'freebaseId': {'type': 'literal', 'value': '/m/03wh8b5'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Barry Fanaro'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2269965'},
#     'freebaseId': {'type': 'literal', 'value': '/m/01jyc2s'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Aber bitte mit Sahne'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q910100'},
#     'freebaseId': {'type': 'literal', 'value': '/m/02z17vc'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Harden M. McConnell'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q193070'},
#     'freebaseId': {'type': 'literal', 'value': '/m/026r8q'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Matt Dillon'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1984460'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0cccw7'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Slime People'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1082849'},
#     'freebaseId': {'type': 'literal', 'value': '/m/054f2k'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Populous'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q228877'},
#     'freebaseId': {'type': 'literal', 'value': '/m/039z_6'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Katherine Moennig'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q152499'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0py8j'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Peninsular War'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q61080767'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0py8j'},
#     'itemLabel': {'type': 'literal', 'value': 'Q61080767'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1193529'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0316bc'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Criminal Law'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2456850'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0s524'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Justice'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7735942'},
#     'freebaseId': {'type': 'literal', 'value': '/m/05mwtf0'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Gateway'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q11886277'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0k0vjvg'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Paavo Kerosuo'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q59473'},
#     'freebaseId': {'type': 'literal', 'value': '/m/01psqj'},
#     'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Užice'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6838626'},
#     'freebaseId': {'type': 'literal', 'value': '/m/06w36wm'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mickey Ferriols'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3442079'},
#     'freebaseId': {'type': 'literal', 'value': '/m/0d330g'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'John Filson'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1387932'},
#     'freebaseId': {'type': 'literal', 'value': '/m/07x3gp'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Lake sturgeon'}}]}}

# %% [markdown]
# ## Saving into json file
#
# finally it's time for us to save the freebase entities into a json file. I choose `json` because the data is not big enough to consider other kind of format and it is more human + machine readable if I save it in `json` format.

# %%
from collections import OrderedDict

# %%
full_mappings = OrderedDict()
simple_mappings = OrderedDict()
for batch_i, result in tqdm(results):
    wikidata_result_bindings = results[batch_i][-1]["results"]["bindings"]
    
    for result_binding in wikidata_result_bindings:
        freebase_id = result_binding["freebaseId"]["value"]
        full_mappings[freebase_id] = dict(
            wikidata_entity_uri=result_binding["item"]["value"],
            label=result_binding["itemLabel"]["value"]
        )
        simple_mappings[freebase_id] = result_binding["itemLabel"]["value"]
# Out:
#   0%|          | 0/872 [00:00<?, ?it/s]

# %%
import json

# %%
with open("simple_questions_v2_freebase_simple_mapping.json", "w") as f:
    json.dump(simple_mappings, f)

with open("simple_questions_v2_freebase_full_mapping.json", "w") as ff:
    json.dump(full_mappings, ff)
