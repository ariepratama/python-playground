# %% [markdown]
# # Get wikidata definition from freebase ids
#
# this notebook will show you how to query freebase ids from wikidata SPARSQL and save it into your local. I will use `simple_questions_v2` freebase ids as an example, on how to download all the entities from wikidata.
#
# Downloading the whole set of entities from wikidata might require large storage, thus I will not do that in this tutorial.

# %%
from datasets import load_dataset
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
train = load_dataset("simple_questions_v2", split="train")
test = load_dataset("simple_questions_v2", split="test")
valid = load_dataset("simple_questions_v2", split="validation")

# %% [markdown]
# collate all the freebase entities from `train`, `test`, and `valid` set.

# %%
entities = set(train["subject_entity"])
entities.update(set(train["object_entity"]))
entities.update(set(test["subject_entity"]))
entities.update(set(test["object_entity"]))
entities.update(set(valid["subject_entity"]))
entities.update(set(valid["object_entity"]))

# %%
entities = list(entities)

# %%
entities[0]
# Out:
# 'www.freebase.com/m/03h2myz'

# %%
transformed_entities = ["/" + "/".join(e.split("/")[1:]) for e in entities]
len(transformed_entities)
# Out:
# 95832

# %%
transformed_entities[0]
# Out:
# '/m/03h2myz'

# %% [markdown]
# ## Constructing the wikidata SPARSQL
#
# This is the sample SPARSQL query to get freebase definition from wikidata. I will need to replace the freebase id, e.g: `/m/017stm`, into something else.
#
# ```
# PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#
# SELECT ?item ?itemLabel
#
# WHERE
# {
#   {?item wdt:P646 "/m/017stm" .}
#
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en"  }
# }
# LIMIT 1
# ```

# %%
# item_template = "{?item wdt:P646 \"{}\" .}"
def construct_items(items):
    item_prefix = '''\t{?item wdt:P646 "'''
    item_suffix = '''" .}'''
    if len(items) == 1:
        return item_prefix + items[0] + item_suffix

    item_lines = [item_prefix + items[0] + item_suffix]
    for i in range(1, len(items)):
        item_line = item_prefix + items[i] + item_suffix
        item_lines.append(
            f"\tUNION {item_line}"
        )
    return "\n".join(item_lines)

def construct_query(items):
    """ construct SPARSQL query to get all freebase entities itemLabel from wikidata.
    """
    query_template = """
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT ?item ?itemLabel 

WHERE
{{
  {}
  SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en"  }}
}}
LIMIT {}
"""
    limit = len(items)
    where_items = construct_items(items)
    return query_template.format(where_items, limit)

# %%
def get_wikidata_definitions(items) -> dict:
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    sparql.setQuery(construct_query(items))
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %% [markdown]
# ## Download labels from wikidata
#
# We should download the mappings from wikidata to prevent us to query multiple times. In this example, I will only use 5 concurrent connections / threads and queue the rest using `ThreadPoolExecutor`. In addition, I will show how to download multiple entities in one network call (I used 110 entities per download request) to make the downloading faster.

# %%
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm

# %%
# max wikidata concurrent api call limit
tp = ThreadPoolExecutor(5)

# %%
# limited by the length of the request
batch_size = 110
iteration_size = len(transformed_entities) // batch_size  + 1

batch_idxs = [
    (i, min(i + batch_size, len(transformed_entities))) 
    for i in range(0, len(transformed_entities), batch_size)
]

batched_entities = [
    transformed_entities[start:end]
    for start, end in batch_idxs
]

# %%
# adding batch index, batch_i, so that we would know which part should be retried
futures = []
for batch_i, batch in enumerate(batched_entities):
    future = tp.submit(get_wikidata_definitions, batch)
    futures.append((batch_i, future))

results = []
for batch_i, future in tqdm(futures):
    results.append((batch_i, future.result()))
# Out:
#   0%|          | 0/872 [00:00<?, ?it/s]

# %% [markdown]
# printing sample of batch

# %%
batched_entities[112]
# Out:
# ['/m/05ql8_',
#  '/m/02sxxf',
#  '/m/026_gmh',
#  '/m/0ch58zq',
#  '/m/082t_',
#  '/m/0n4p401',
#  '/m/05p_3j',
#  '/m/026vkrm',
#  '/m/0by3lg',
#  '/m/07j83t',
#  '/m/04n6h0f',
#  '/m/0dq1_0q',
#  '/m/01by3wz',
#  '/m/04wcdz_',
#  '/m/04c3g_d',
#  '/m/0jwn_z',
#  '/m/01mkqjb',
#  '/m/0zv6y8w',
#  '/m/027_mgb',
#  '/m/06tbj8',
#  '/m/0k3jc',
#  '/m/03cdry0',
#  '/m/05wgvs',
#  '/m/0j3p16k',
#  '/m/096jl',
#  '/m/0h1mt',
#  '/m/01b20k',
#  '/m/08z9lv',
#  '/m/048wz_3',
#  '/m/02xb6hh',
#  '/m/0dz2h',
#  '/m/0g6x4yc',
#  '/m/079k4mp',
#  '/m/0y5pvgm',
#  '/m/02rfpgx',
#  '/m/0crsrqb',
#  '/m/0mgcspn',
#  '/m/04v8rc7',
#  '/m/093ldx',
#  '/m/0x1klxq',
#  '/m/0jqw_n0',
#  '/m/051tfx',
#  '/m/047c36v',
#  '/m/06f5j',
#  '/m/02ww4b2',
#  '/m/02cw4l',
#  '/m/0mzbr35',
#  '/m/0d77t7v',
#  '/m/02qh7vh',
#  '/m/0dh53',
#  '/m/03779m',
#  '/m/02w8gwf',
#  '/m/047pb6z',
#  '/m/09kr66',
#  '/m/02w3w29',
#  '/m/03qqt__',
#  '/m/0qnqnm',
#  '/m/0mmtzvx',
#  '/m/05qdwy',
#  '/m/08_y0n',
#  '/m/01qf97l',
#  '/m/03g_z9',
#  '/m/0g4scz1',
#  '/m/0mjhnst',
#  '/m/040qdvp',
#  '/m/040rv',
#  '/m/02p61k',
#  '/m/02r6_f0',
#  '/m/032ytl',
#  '/m/09054g',
#  '/m/0d7z5y',
#  '/m/05c0ds_',
#  '/m/0xpbq',
#  '/m/01jnc6b',
#  '/m/0knbcq8',
#  '/m/030k713',
#  '/m/023lhgk',
#  '/m/0rg52',
#  '/m/0c8l996',
#  '/m/014rc3b',
#  '/m/05dvf1v',
#  '/m/0j440t4',
#  '/m/07kjk4g',
#  '/m/09v58_q',
#  '/m/0yzh_r',
#  '/m/03qxyk',
#  '/m/0f2pxn',
#  '/m/0l0d6xl',
#  '/m/0f18ff9',
#  '/m/05mqtn',
#  '/m/06gjk9',
#  '/m/038bbc',
#  '/m/0806bnk',
#  '/m/01713lb',
#  '/m/01lqqw8',
#  '/m/034_fxv',
#  '/m/03y7_cx',
#  '/m/02vxtqc',
#  '/m/02hltb9',
#  '/m/0265r3z',
#  '/m/04fd7cx',
#  '/m/01_rbq',
#  '/m/0by6wct',
#  '/m/0s2ck2',
#  '/m/0jr0h',
#  '/m/0dq0lz8',
#  '/m/016t7dx',
#  '/m/0b537m',
#  '/m/0fpfpm',
#  '/m/0f5_sl9']

# %%
results[112]
# Out:
# (112,
#  {'head': {'vars': ['item', 'itemLabel']},
#   'results': {'bindings': [{'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q738748'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sittwe'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q169902'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Prince Aimone, 4th Duke of Aosta'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q832085'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Miguel Cané'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q52669674'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Ferenc Paláncz'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q257424'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mickey'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q12040838'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Innocence'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q7311671'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Remember Me'}},
#     {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q65321'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Wolfgang Petersen'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q7045646'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nobelity'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q313049'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Chris Hardwick'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q511684'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Stewart-Haas Racing'}},
#     {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43371'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Chris Meledandri'}},
#     {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q28361'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Belize Barrier Reef'}},
#     {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q54160'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Hampden County'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q1368007'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Richard Arnell'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q4821906'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Aung San Oo'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q1041618'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': "Carla's Song"}},
#     {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q41142'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Jane Fonda'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q7881461'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Umed Khabibulloev'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q5525118'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Gary Geiger'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q122960'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Rococo'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q5560594'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Gil Reavill'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q205218'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dalarna'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q354888'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'David Eddings'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q4885131'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Bemis Park Landmark Heritage District'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q7373116'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Roy Marlin Voris'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q6287450'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Joseph Tomane'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q330224'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'George Eastman'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q165557'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Robert E. Lee'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q4217711'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Cathedral Preparatory Seminary'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q1106818'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'UniMás'}},
#     {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q58854'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'literary criticism'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q7106129'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Oscar Marx'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q589359'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tekken 2'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q5230014'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Dave Trumfio'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q1140588'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Russian Americans'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q7245631'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Priscilla Weems'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q6288092'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Joseph Xavier Grant'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q4443441'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Casey Stratton'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q573587'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Brenden Morrow'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q2166226'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Alien Hunter'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q7358675'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Roger Moore'}},
#     {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2619'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'June 12'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q6416185'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Kirsty Wark'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q668659'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Lago di Vogorno'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q4791274'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Arizona Christian University'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q5419358'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Excalibur'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q6656900'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Live at the North Sea Jazz Festival, 1980'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q1175569'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'David Mayer de Rothschild'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q516342'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Johnny Van Zant'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q661096'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Carteret'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q2430894'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Danielson'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q6011829'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'In the Basement'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q7152481'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Paul Merton in Europe'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q7057851'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Northeast Coast Campaign'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q6650413'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Little Indian'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q11574569'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ikitsuki'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q2710217'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Life'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q3225437'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'The Little Friend'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q733677'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Match Point'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q687600'},
#      'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Dead'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q10486395'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Sam Slocombe'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q1173180'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Dave Douglas'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q221506'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': '11912 Piedade'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q1701634'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'John Rutledge, Jr.'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q6215356'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Johan Sara'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q761838'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Elmer Ambrose Sperry'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q1758092'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'From the Manger to the Cross'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q735081'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'Chhabi Biswas'}},
#     {'item': {'type': 'uri',
#       'value': 'http://www.wikidata.org/entity/Q5628289'},
#      'itemLabel': {'xml:lang': 'en',
#       'type': 'literal',
#       'value': 'H. H. Richardson Complex'}}]}})

# %% [markdown]
# ## Saving into json file
#
# finally it's time for us to save the freebase entities into a json file. I choose `json` because the data is not big enough to consider other kind of format and it is more human + machine readable if I save it in `json` format.

# %%
from collections import OrderedDict

# %%
full_mappings = OrderedDict()
simple_mappings = OrderedDict()
for batch_i, result in tqdm(results):
    freebase_entity_ids = batched_entities[batch_i]
    wikidata_result_bindings = results[batch_i][-1]["results"]["bindings"]
    
    for freebase_id, result_binding in zip(freebase_entity_ids, wikidata_result_bindings):
        full_mappings[freebase_id] = dict(
            wikidata_entity_uri=result_binding["item"]["value"],
            label=result_binding["itemLabel"]["value"]
        )
        simple_mappings[freebase_id] = result_binding["itemLabel"]["value"]
# Out:
#   0%|          | 0/872 [00:00<?, ?it/s]

# %%
import json

# %%
with open("simple_questions_v2_freebase_simple_mapping.json", "w") as f:
    json.dump(simple_mappings, f)

with open("simple_questions_v2_freebase_full_mapping.json", "w") as ff:
    json.dump(full_mappings, ff)
